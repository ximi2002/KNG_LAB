# %% [markdown]
# ### 数据集类

# %%
import torch
from torch.utils.data import Dataset

data_path=r"./SMS+Spam+Collection/SMSSpamCollection"

# %%
class MyDataset(Dataset):
    def __init__(self):
        self.lines=open(data_path).readlines()
    
    def __getitem__(self, index):
        cur_line=self.lines[index].strip()
        label =cur_line[:4].strip()
        content=cur_line[4:].strip()
        return label,content
    
    def __len__(self):
        return len(self.lines)

# %%
my_dataset=MyDataset()
print(my_dataset[0])
# Out:
# ('ham', 'Go until jurong point, crazy.. Available only in bugis n great world la e buffet... Cine there got amore wat...')

# %% [markdown]
# #### 数据预处理（数据加载器）

# %%
from torch.utils.data import DataLoader

data_loader=DataLoader(dataset=my_dataset,batch_size=3,shuffle=True)

for i in data_loader:
    print(i)
# Out:
# [('ham', 'ham', 'ham'), ("I'm on my way home. Went to change batt 4 my watch then go shop a bit lor.", 'Actually fuck that, just do whatever, do find an excuse to be in tampa at some point before january though', "If you're still up, maybe leave the credit card so I can get gas when I get back like he told me to")]
# [('spam', 'ham', 'ham'), ('Knock Knock Txt whose there to 80082 to enter r weekly draw 4 a £250 gift voucher 4 a store of yr choice. T&Cs www.tkls.com age16 to stoptxtstop£1.50/week', "Come round, it's .", 'Hi dis is yijue i would be happy to work wif ü all for gek1510...')]
# [('ham', 'ham', 'ham'), ("Sorry, I'll call later", '.Please charge my mobile when you get up in morning.', 'Happy birthday to you....dear.with lots of love.rakhesh NRI')]
# ...

# %% [markdown]
# ### pytorch自带数据

# %%
import torchvision
from torchvision.datasets import MNIST

# %%
mnist=MNIST(root="./HandWritingRecoData",train=True,download=False)

# %%
print(mnist)
# Out:
# Dataset MNIST
#     Number of datapoints: 60000
#     Root location: ./HandWritingRecoData
#     Split: Train

# %%
print(mnist[0])
# Out:
# (<PIL.Image.Image image mode=L size=28x28 at 0x7F590F558550>, 5)

# %%
mnist[0][0]
# Out:
# <PIL.Image.Image image mode=L size=28x28 at 0x7F5905F16390>
